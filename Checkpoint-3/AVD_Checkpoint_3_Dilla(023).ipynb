# %% [markdown]
# Nama: Dilla Maharani
#
# NIM: 2409115023
#
# Kelas: A'24

# %% [markdown]
# #**💡CHECKPOINT 1⋆｡°✎ᝰ ˎˊ˗**

# %% [markdown]
# #**BUSINESS UNDERSTANDING ‧₊˚⋅📃✎**

# %% [markdown]
# ##Business Objective

# %% [markdown]
# Proyek ini bertujuan untuk menganalisis pola belanja pelanggan grosir berdasarkan jenis produk yang mereka beli. Dengan analisis ini, pemasok, pengecer, dan manajer bisnis dapat mengelompokkan pelanggan, menyesuaikan strategi pemasaran, serta mengelola stok barang secara lebih optimal agar sesuai dengan permintaan pasar dan meningkatkan efisiensi operasional.

# %% [markdown]
# ##Assess Situation

# %% [markdown]
# Industri grosir dihadapkan pada tantangan seperti perubahan permintaan, tren pasar yang dinamis, dan persaingan ketat dalam distribusi. Oleh karena itu, perusahaan perlu memahami pola perilaku pelanggan untuk mengidentifikasi segmen yang paling menguntungkan, menyesuaikan strategi penetapan harga, serta memastikan stok barang tetap tersedia dengan optimal. Melalui analisis data pembelian, bisnis dapat mengungkap pola belanja pelanggan dan merancang strategi yang lebih efektif guna meningkatkan loyalitas pelanggan serta efisiensi operasional.

# %% [markdown]
# ## Data Mining Goals

# %% [markdown]
# Proyek ini bertujuan untuk menerapkan data mining dalam menganalisis pola pembelian pelanggan grosir berdasarkan kategori produk yang mereka konsumsi, sehingga dapat mengelompokkan pelanggan dan memahami preferensi belanja mereka. Dengan menggali hubungan antara volume pembelian, jenis produk, dan karakteristik pelanggan, analisis ini dapat membantu bisnis dalam merancang strategi pemasaran yang lebih tepat, menentukan harga yang lebih kompetitif, serta mengelola stok barang dengan lebih efisien. Selain itu, wawasan yang diperoleh dari data ini dapat dimanfaatkan untuk meningkatkan loyalitas pelanggan dan mendukung pengambilan keputusan yang lebih strategis dalam operasional bisnis grosir.

# %% [markdown]
# ##Project Plan

# %% [markdown]
# 1️. Memahami Data
#
# Melakukan eksplorasi dataset untuk mengenali fitur-fitur yang tersedia, seperti jenis produk, total nilai transaksi per pelanggan, serta kategori pelanggan berdasarkan pola pembelian mereka.
#
# 2️. Menyiapkan Data
#
# Melakukan pembersihan data dengan menghilangkan entri yang tidak relevan atau duplikat.
# Menyesuaikan format data numerik dan kategorikal agar siap digunakan dalam proses analisis.
#
# 3️. Menganalisis & Memvisualisasikan
#
# Mengidentifikasi tren pembelian berdasarkan kategori produk serta segmen pelanggan.
# Membuat visualisasi data, seperti grafik dan diagram, untuk memahami distribusi serta hubungan antar variabel.
#
# 4️. Mengelompokkan Pelanggan
#
# Menerapkan teknik clustering untuk membagi pelanggan ke dalam beberapa segmen berdasarkan kebiasaan belanja mereka.
# Menganalisis karakteristik dari setiap segmen guna merancang strategi pemasaran yang lebih efektif.
#
# 5️. Mengevaluasi Hasil & Menyusun Laporan
#
# Menilai keakuratan serta manfaat dari model yang telah dibuat.
# Menyusun laporan yang berisi ringkasan temuan utama serta rekomendasi bisnis berbasis data.
#
# 6️. Menggunakan Hasil untuk Keputusan Bisnis
#
# Wawasan yang diperoleh dari analisis ini akan membantu bisnis dalam merancang strategi pemasaran yang lebih personal, mengelola stok produk dengan lebih optimal, serta meningkatkan efisiensi operasional guna menarik lebih banyak pelanggan dan meningkatkan profitabilitas.

# %% [markdown]
# #**💡CHECKPOINT 2⋆｡°✎ᝰ ˎˊ˗**

# %% [markdown]
# # **DATA UNDERSTANDING ‧₊˚⋅📃✎**
#
# Dataset ini diambil dari: [Wholesale Customers Data](https://www.kaggle.com/datasets/saurabhbadole/wholesale-customers-data) ୧ ‧₊˚  🖇️📁 ⋆｡°✩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import LinearSegmentedColormap

# %% [markdown]
# ## MEMBACA DATA ── .✦

# %%
file = "/content/drive/MyDrive/avd/Wholesale customers data.csv"

df = pd.read_csv(file)
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# ...

# %% [markdown]
# ## PENGECEKAN STRUKTUR DATA ── .✦

# %%
print("Menampilkan 3 Row Data Teratas:")

df.head(3)
# Out:
# Menampilkan 3 Row Data Teratas:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844

# %%
print("Menampilkan 3 Row Data Terbawah:")

df.tail(3)
# Out:
# Menampilkan 3 Row Data Terbawah:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 437        1867
# 438        2125
# 439          52

# %%
print ("Menampilkan ringkasan dataset, termasuk jumlah baris, kolom, dan tipe data: ")

df.info()
# Out:
# Menampilkan ringkasan dataset, termasuk jumlah baris, kolom, dan tipe data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %%
print("Menampilkan jumlah baris dan kolom data:")

df.shape
# Out:
# Menampilkan jumlah baris dan kolom data:
# (440, 8)

# %%
print("Menampilkan tipe data setiap kolom:")

df.dtypes
# Out:
# Menampilkan tipe data setiap kolom:
# Channel             int64
# Region              int64
# Fresh               int64
# Milk                int64
# Grocery             int64
# Frozen              int64
# Detergents_Paper    int64
# Delicassen          int64
# dtype: object

# %% [markdown]
# ## STATISTIK DESKRIPTIF ── .✦

# %%
print("Menampilkan statistik ringkasan seperti mean, median, min, max, dan kuartil data:")

df.describe()
# Out:
# Menampilkan statistik ringkasan seperti mean, median, min, max, dan kuartil data:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# ...

# %%
print ("Menghitung jumlah kemunculan nilai unik dalam kolom tertentu:")

df.value_counts()
# Out:
# Menghitung jumlah kemunculan nilai unik dalam kolom tertentu:
# Channel  Region  Fresh  Milk   Grocery  Frozen  Detergents_Paper  Delicassen
# 1        1       514    8323   6869     529     93                1040          1
#          3       43088  2100   2609     1200    1107              823           1
# 2        1       1073   9679   15445    61      5980              1265          1
#                  572    9763   22182    2221    4882              2563          1
#                  18     7504   15205    1285    4797              6372          1
#                                                                                ..
# 1        3       4446   906    1238     3576    153               1014          1
#                  4420   5139   2661     8872    1321              181           1
#                  4020   3234   1498     2395    264               255           1
#                  3884   3801   1641     876     397               4829          1
# ...

# %%
print("Menghitung Rata-Rata: ")

df.mean()
# Out:
# Menghitung Rata-Rata:
# Channel                 1.322727
# Region                  2.543182
# Fresh               12000.297727
# Milk                 5796.265909
# Grocery              7951.277273
# Frozen               3071.931818
# Detergents_Paper     2881.493182
# Delicassen           1524.870455
# dtype: float64

# %%
print("Menghitung Median: ")

df.median()
# Out:
# Menghitung Median:
# Channel                1.0
# Region                 3.0
# Fresh               8504.0
# Milk                3627.0
# Grocery             4755.5
# Frozen              1526.0
# Detergents_Paper     816.5
# Delicassen           965.5
# dtype: float64

# %%
print("Menghitung Standar Deviasi: ")

df.std()
# Out:
# Menghitung Standar Deviasi:
# Channel                 0.468052
# Region                  0.774272
# Fresh               12647.328865
# Milk                 7380.377175
# Grocery              9503.162829
# Frozen               4854.673333
# Detergents_Paper     4767.854448
# Delicassen           2820.105937
# dtype: float64

# %%
print("Menghitung korelasi antar kolom numerik: ")

df.corr()
# Out:
# Menghitung korelasi antar kolom numerik:
#                    Channel    Region     Fresh      Milk   Grocery    Frozen  \
# Channel           1.000000  0.062028 -0.169172  0.460720  0.608792 -0.202046
# Region            0.062028  1.000000  0.055287  0.032288  0.007696 -0.021044
# Fresh            -0.169172  0.055287  1.000000  0.100510 -0.011854  0.345881
# Milk              0.460720  0.032288  0.100510  1.000000  0.728335  0.123994
# Grocery           0.608792  0.007696 -0.011854  0.728335  1.000000 -0.040193
# Frozen           -0.202046 -0.021044  0.345881  0.123994 -0.040193  1.000000
# Detergents_Paper  0.636026 -0.001483 -0.101953  0.661816  0.924641 -0.131525
# Delicassen        0.056011  0.045212  0.244690  0.406368  0.205497  0.390947
#
#                   Detergents_Paper  Delicassen
# Channel                   0.636026    0.056011
# Region                   -0.001483    0.045212
# Fresh                    -0.101953    0.244690
# ...

# %% [markdown]
# Kolom Grocery, Milk, dan Detergents_Paper menunjukkan korelasi yang tinggi, sehingga dapat digunakan dalam analisis untuk memprediksi pola pembelian atau mengelompokkan pelanggan. Sementara itu, kolom Region memiliki pengaruh yang sangat kecil terhadap variabel lainnya, sehingga bisa dipertimbangkan untuk dihapus dari analisis selanjutnya.

# %% [markdown]
# # **DATA PREPARATION ‧₊˚⋅📃✎**

# %% [markdown]
# ## DATA CLEANING ── .✦

# %% [markdown]
# ### Missing Values ⋆⭒˚.⋆

# %% [markdown]
# #### Melihat Missing Values

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Channel             0.0
# Region              0.0
# Fresh               0.0
# Milk                0.0
# Grocery             0.0
# Frozen              0.0
# Detergents_Paper    0.0
# Delicassen          0.0
# dtype: float64

# %% [markdown]
# Berdasarkan hasil di atas, dapat disimpulkan bahwa tidak terdapat missing values dalam dataset, karena semua kolom memiliki nilai 0.0%. Dengan demikian, tidak ada data yang hilang, dan tidak diperlukan langkah tambahan untuk menangani missing values dalam dataset ini.

# %% [markdown]
# ### Duplicated Values ⋆⭒˚.⋆

# %% [markdown]
# #### Melihat Duplicated Values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Channel, Region, Fresh, Milk, Grocery, Frozen, Detergents_Paper, Delicassen]
# Index: []

# %% [markdown]
# Berdasarkan hasil di atas, tidak ada data yang ditampilkan, yang menandakan bahwa dataset tidak mengandung nilai duplikat. Dengan demikian, tidak diperlukan tindakan lebih lanjut untuk menangani duplikasi dalam data ini.

# %% [markdown]
# ### Outliers ⋆⭒˚.⋆

# %% [markdown]
# #### Pengecekan Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# Channel                      0.000000
# Region                       0.000000
# Fresh                        4.545455
# Milk                         6.363636
# Grocery                      5.454545
# Frozen                       9.772727
# Detergents_Paper             6.818182
# Delicassen                   6.136364

# %% [markdown]
# Berdasarkan hasil di atas, persentase outlier yang terdeteksi menunjukkan bahwa kolom Fresh, Milk, Grocery, Frozen, Detergents_Paper, dan Delicassen mengandung nilai outlier, sementara kolom Channel dan Region tidak mengandung nilai outlier.

# %% [markdown]
# #### Melakukan Imputasi

# %%
columns_to_impute = ["Fresh", "Milk", "Grocery", "Frozen", "Detergents_Paper", "Delicassen" ]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)
# Out:
# <ipython-input-67-a721fdb9201e>:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[1.266900e+04 7.057000e+03 6.353000e+03 1.326500e+04 2.261500e+04
#  9.413000e+03 1.212600e+04 7.579000e+03 5.963000e+03 6.006000e+03
#  3.366000e+03 1.314600e+04 3.171400e+04 2.121700e+04 2.465300e+04
#  1.025300e+04 1.020000e+03 5.876000e+03 1.860100e+04 7.780000e+03
#  1.754600e+04 5.567000e+03 3.127600e+04 2.637300e+04 2.264700e+04
#  1.616500e+04 9.898000e+03 1.427600e+04 4.113000e+03 3.764275e+04
#  1.881500e+04 2.612000e+03 2.163200e+04 2.972900e+04 1.502000e+03
#  6.880000e+02 2.995500e+04 1.516800e+04 4.591000e+03 3.764275e+04
#  2.402500e+04 1.917600e+04 1.085000e+04 6.300000e+02 9.670000e+03
#  5.181000e+03 3.103000e+03 3.764275e+04 1.151900e+04 4.967000e+03
#  6.269000e+03 3.347000e+03 3.764275e+04 4.910000e+02 2.732900e+04
#  5.264000e+03 4.098000e+03 5.417000e+03 1.377900e+04 6.137000e+03
# ...

# %% [markdown]
# Kode ini menangani outlier tanpa menghapus data dengan menyesuaikan nilai ekstrem agar tetap berada dalam batas wajar berdasarkan distribusi IQR. Pendekatan ini memastikan data tetap akurat dan lebih seimbang untuk analisis atau penerapan machine learning tanpa kehilangan informasi penting.

# %% [markdown]
# #### Melakukan Pengecekan Ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# Channel                           0.0
# Region                            0.0
# Fresh                             0.0
# Milk                              0.0
# Grocery                           0.0
# Frozen                            0.0
# Detergents_Paper                  0.0
# Delicassen                        0.0

# %% [markdown]
# Setelah diimputasi, persentase outlier menjadi 0.0%

# %% [markdown]
# ### Inconsistent Values ⋆⭒˚.⋆

# %% [markdown]
# #### Pengecekan Inconsistent Values

# %%
df['Fresh'] = df['Fresh'].apply(lambda x: abs(x) if x < 0 else x)
print(df['Fresh'])
# Out:
# 0      12669.00
# 1       7057.00
# 2       6353.00
# 3      13265.00
# 4      22615.00
#          ...
# 435    29703.00
# 436    37642.75
# 437    14531.00
# 438    10290.00
# 439     2787.00
# Name: Fresh, Length: 440, dtype: float64

# %% [markdown]
# Data kolom "Fresh" sudah konsisten karena tidak ada yang di bawah 0.

# %%
df['Milk'] = df['Milk'].apply(lambda x: abs(x) if x < 0 else x)
print(df['Milk'])
# Out:
# 0       9656.0
# 1       9810.0
# 2       8808.0
# 3       1196.0
# 4       5410.0
#         ...
# 435    12051.0
# 436     1431.0
# 437    15488.0
# 438     1981.0
# 439     1698.0
# Name: Milk, Length: 440, dtype: float64

# %% [markdown]
# Data kolom "Milk" sudah konsisten karena tidak ada yang di bawah 0.

# %%
df['Grocery'] = df['Grocery'].apply(lambda x: abs(x) if x < 0 else x)
print(df['Grocery'])
# Out:
# 0       7561.000
# 1       9568.000
# 2       7684.000
# 3       4221.000
# 4       7198.000
#          ...
# 435    16027.000
# 436      764.000
# 437    23409.875
# 438     2232.000
# 439     2510.000
# Name: Grocery, Length: 440, dtype: float64

# %% [markdown]
# Data kolom "Grocery" sudah konsisten karena tidak ada yang di bawah 0.

# %%
df['Frozen'] = df['Frozen'].apply(lambda x: abs(x) if x < 0 else x)
print(df['Frozen'])
# Out:
# 0       214.00
# 1      1762.00
# 2      2405.00
# 3      6404.00
# 4      3915.00
#         ...
# 435    7772.25
# 436    4510.00
# 437     437.00
# 438    1038.00
# 439      65.00
# Name: Frozen, Length: 440, dtype: float64

# %% [markdown]
# Data kolom "Frozen" sudah konsisten karena tidak ada yang di bawah 0.

# %%
df['Detergents_Paper'] = df['Detergents_Paper'].apply(lambda x: abs(x) if x < 0 else x)
print(df['Detergents_Paper'])
# Out:
# 0      2674.000
# 1      3293.000
# 2      3516.000
# 3       507.000
# 4      1777.000
#          ...
# 435     182.000
# 436      93.000
# 437    9419.875
# 438     168.000
# 439     477.000
# Name: Detergents_Paper, Length: 440, dtype: float64

# %% [markdown]
# Data kolom "Detergents_Paper" sudah konsisten karena tidak ada yang di bawah 0.

# %%
df['Delicassen'] = df['Delicassen'].apply(lambda x: abs(x) if x < 0 else x)
print(df['Delicassen'])
# Out:
# 0      1338.00
# 1      1776.00
# 2      3938.25
# 3      1788.00
# 4      3938.25
#         ...
# 435    2204.00
# 436    2346.00
# 437    1867.00
# 438    2125.00
# 439      52.00
# Name: Delicassen, Length: 440, dtype: float64

# %% [markdown]
# Data kolom "Delicassen" sudah konsisten karena tidak ada yang di bawah 0.

# %% [markdown]
# Karena semua data sudah konsisten, tidak perlu dilakukan penanganan.

# %% [markdown]
# ## CONSTRUCT DATA ── .✦

# %%
df["Total"] = df["Fresh"] + df["Milk"] + df["Grocery"] + df["Frozen"] + df["Detergents_Paper"] + df["Delicassen"]

print(df.head())
# Out:
#    Channel  Region    Fresh    Milk  Grocery  Frozen  Detergents_Paper  \
# 0        2       3  12669.0  9656.0   7561.0   214.0            2674.0
# 1        2       3   7057.0  9810.0   9568.0  1762.0            3293.0
# 2        2       3   6353.0  8808.0   7684.0  2405.0            3516.0
# 3        1       3  13265.0  1196.0   4221.0  6404.0             507.0
# 4        2       3  22615.0  5410.0   7198.0  3915.0            1777.0
#
#    Delicassen     Total
# 0     1338.00  34112.00
# 1     1776.00  33266.00
# 2     3938.25  32704.25
# 3     1788.00  27381.00
# 4     3938.25  44853.25

# %% [markdown]
# Menambahkan kolom "Total" pada dataset

# %%
df
# Out:
#      Channel  Region     Fresh     Milk    Grocery   Frozen  Detergents_Paper  \
# 0          2       3  12669.00   9656.0   7561.000   214.00          2674.000
# 1          2       3   7057.00   9810.0   9568.000  1762.00          3293.000
# 2          2       3   6353.00   8808.0   7684.000  2405.00          3516.000
# 3          1       3  13265.00   1196.0   4221.000  6404.00           507.000
# 4          2       3  22615.00   5410.0   7198.000  3915.00          1777.000
# ..       ...     ...       ...      ...        ...      ...               ...
# 435        1       3  29703.00  12051.0  16027.000  7772.25           182.000
# 436        1       3  37642.75   1431.0    764.000  4510.00            93.000
# 437        2       3  14531.00  15488.0  23409.875   437.00          9419.875
# 438        1       3  10290.00   1981.0   2232.000  1038.00           168.000
# 439        1       3   2787.00   1698.0   2510.000    65.00           477.000
#
#      Delicassen     Total
# ...

# %% [markdown]
# Menambahkan kolom "Total" membantu menyederhanakan analisis, mempermudah perbandingan, dan meningkatkan kualitas insight dari data.

# %% [markdown]
# ## DATA REDUCTION ── .✦

# %%
df = df.drop('Region', axis=1)

# %% [markdown]
# Menghapus kolom "Region" pada dataset.

# %%
df
# Out:
#      Channel     Fresh     Milk    Grocery   Frozen  Detergents_Paper  \
# 0          2  12669.00   9656.0   7561.000   214.00          2674.000
# 1          2   7057.00   9810.0   9568.000  1762.00          3293.000
# 2          2   6353.00   8808.0   7684.000  2405.00          3516.000
# 3          1  13265.00   1196.0   4221.000  6404.00           507.000
# 4          2  22615.00   5410.0   7198.000  3915.00          1777.000
# ..       ...       ...      ...        ...      ...               ...
# 435        1  29703.00  12051.0  16027.000  7772.25           182.000
# 436        1  37642.75   1431.0    764.000  4510.00            93.000
# 437        2  14531.00  15488.0  23409.875   437.00          9419.875
# 438        1  10290.00   1981.0   2232.000  1038.00           168.000
# 439        1   2787.00   1698.0   2510.000    65.00           477.000
#
#      Delicassen     Total
# 0       1338.00  34112.00
# 1       1776.00  33266.00
# 2       3938.25  32704.25
# ...

# %% [markdown]
# Kolom "Region" dihapus karena Region tidak berperan langsung dalam menentukan seberapa banyak mereka membeli produk.

# %% [markdown]
# #**💡CHECKPOINT 3⋆｡°✎ᝰ ˎˊ˗**

# %% [markdown]
# #**MATPLOTLIB & SEABORN ‧₊˚⋅📃✎**

# %% [markdown]
# ## Comparison ── .✦

# %%
plt.figure(figsize=(8, 5))
plt.bar(df[['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']].sum().index, df[['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']].sum().values, color='pink')
plt.title('Jumlah Penjualan Produk')
plt.xlabel('Produk')
plt.ylabel('Total')
plt.xticks(rotation=45)
plt.show()
print(df[['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']].sum())
# Out:
# Fresh               4997330.00
# Milk                2221380.50
# Grocery             3184005.00
# Frozen              1103117.75
# Detergents_Paper    1052751.25
# Delicassen           557354.75
# dtype: float64

# %% [markdown]
# Berdasarkan bar chart di atas, kategori "Fresh" memiliki total penjualan tertinggi sebesar 4,997,330.00, diikuti oleh "Grocery" sebesar 3,184,005.00 dan "Milk" sebesar 2,221,380.50, menunjukkan bahwa pelanggan lebih banyak membeli produk segar dan kebutuhan pokok. Sebaliknya, kategori seperti "Frozen," "Detergents_Paper," dan "Delicassen" memiliki total penjualan yang lebih rendah, masing-masing sebesar 1,103,117.75, 1,052,751.25, dan 557,354.75, menandakan bahwa permintaan terhadap kategori ini masih lebih terbatas.
#
# Untuk memaksimalkan potensi ini, perusahaan dapat memastikan stok untuk kategori utama seperti "Fresh," "Grocery," dan "Milk" selalu tersedia, disertai promosi menarik seperti diskon atau loyalty rewards untuk mempertahankan daya tarik pelanggan. Selain itu, diversifikasi produk atau penawaran khusus seperti bundling dapat membantu meningkatkan minat pada kategori dengan penjualan lebih rendah. Edukasi pelanggan melalui kampanye digital tentang manfaat kategori tertentu serta analisis pola musiman juga dapat menjadi strategi efektif untuk memenuhi kebutuhan pelanggan dan meningkatkan penjualan secara keseluruhan. Dengan langkah-langkah ini, perusahaan dapat menciptakan keseimbangan yang lebih baik antara kategori utama dan kategori yang kurang diminati.

# %% [markdown]
# ## Distribution ── .✦

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df[['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']], palette=["#ffe6f2", "#ffb3c6", "#ff99cc", "#ff80a4", "#ff4d79","#cc0066"])
plt.xticks(rotation=45)
plt.title("Distribusi Pola Belanja Pelanggan Berdasarkan Jenis Produk")
plt.ylabel("Nilai Pembelian (dalam satuan yang tersedia)")
plt.xlabel("Kategori Produk")
plt.show()

# %% [markdown]
# Dari boxplot di atas, terlihat bahwa kategori "Fresh" dan "Grocery" memiliki variasi pembelian yang besar, dengan beberapa pelanggan membeli dalam jumlah banyak. Sebaliknya, kategori lain cenderung lebih stabil dan konsisten dalam pola pembeliannya.
#
# Melihat hal ini, perusahaan bisa menerapkan program loyalitas atau memberikan diskon untuk pembelian dalam jumlah besar agar pelanggan semakin tertarik. Untuk kategori seperti "Delicassen" yang pembeliannya lebih sedikit, strategi seperti meningkatkan promosi, menambah visibilitas produk, atau menyusun pemasaran yang lebih menarik bisa dicoba untuk menarik perhatian pelanggan.

# %% [markdown]
# ## Relationship ── .✦

# %%
pink_pastel_cmap = LinearSegmentedColormap.from_list("pink_pastel", ["#ffe6f2", "#ffb3c6", "#ff80a4", "#ff4d79"])
plt.figure(figsize=(8, 5))
sns.heatmap(df[['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen', 'Total']].corr(), annot=True, cmap=pink_pastel_cmap, fmt='.2f')
plt.title('Heatmap Korelasi Antar Produk')
plt.show()

# %% [markdown]
# Dari heatmap korelasi di atas, terlihat bahwa beberapa kategori produk memiliki hubungan pembelian yang erat. Contohnya, kategori "Milk" dan "Grocery" memiliki korelasi yang sangat kuat, menunjukkan bahwa pelanggan sering membeli kedua kategori ini bersamaan. Hal serupa juga terlihat pada "Grocery" dan "Detergents_Paper", yang memiliki hubungan sangat tinggi, menandakan bahwa pelanggan cenderung membeli kebutuhan rumah tangga bersama bahan makanan. Selain itu, "Grocery", "Milk", dan "Fresh" memiliki korelasi tinggi dengan total penjualan, menegaskan bahwa kategori ini merupakan kontributor utama pendapatan. Sebaliknya, "Frozen" dan "Fresh" memiliki korelasi positif yang rendah, yang mungkin berarti pelanggan lebih sering memilih salah satu dari kedua kategori ini daripada membeli keduanya sekaligus. Sementara itu, kategori "Delicassen" memiliki korelasi sedang, yang menunjukkan bahwa produk ini memiliki basis pelanggan yang lebih spesifik.
#
# Berdasarkan insight ini, perusahaan dapat mengembangkan strategi promosi seperti bundling produk untuk kategori dengan korelasi tinggi, seperti "Milk" dan "Grocery", atau "Grocery" dan "Detergents_Paper", guna mendorong pembelian kombinasi. Penempatan produk berdekatan di toko juga dapat meningkatkan pembelian impulsif. Untuk kategori dengan korelasi rendah seperti "Frozen" dan "Fresh", perusahaan perlu menggali lebih dalam untuk memahami preferensi pelanggan dan menawarkan promosi yang lebih relevan, seperti diskon musiman. Kategori "Delicassen" dapat ditingkatkan melalui promosi khusus atau kampanye pemasaran yang menarik perhatian pelanggan terhadap keunikan produk ini. Selain itu, perusahaan juga dapat mengatur stok berdasarkan pola korelasi, sehingga produk dengan hubungan pembelian yang tinggi selalu tersedia untuk memenuhi permintaan pelanggan. Strategi ini tidak hanya akan meningkatkan penjualan tetapi juga memberikan pengalaman belanja yang lebih baik bagi pelanggan.

# %% [markdown]
# ## Composition ── .✦

# %%
plt.figure(figsize=(8, 8))
df_mean = df[['Fresh','Milk','Grocery','Frozen','Detergents_Paper','Delicassen']].mean()
plt.pie(df_mean, labels=df_mean.index, autopct='%1.1f%%', startangle=140, colors=['pink', 'cornsilk', 'aliceblue', 'linen', 'thistle', 'lavender'])
plt.title("Komposisi Rata-rata Pembelian per Kategori Produk")
plt.show()

# %% [markdown]
# Berdasarkan pie chart di atas, kategori "Fresh" mendominasi dengan kontribusi terbesar, yaitu 38.1%, diikuti oleh "Grocery" sebesar 24.3% dan "Milk" sebesar 16.9%. Sementara itu, kategori "Frozen", "Detergents_Paper", dan "Delicassen" memiliki kontribusi yang lebih kecil, masing-masing sebesar 8.4%, 8.0%, dan 4.2%. Hal ini menunjukkan bahwa pelanggan lebih fokus pada pembelian produk segar dan kebutuhan pokok.
#
# Untuk menjaga performa ini, perusahaan perlu memastikan stok kategori utama seperti "Fresh", "Grocery", dan "Milk" selalu tersedia. Di sisi lain, kategori dengan kontribusi rendah seperti "Frozen", "Detergents_Paper", dan "Delicassen" dapat ditingkatkan melalui promosi menarik, seperti diskon atau bundling produk. Strategi pemasaran tambahan, seperti edukasi produk melalui kampanye digital atau menampilkan testimoni pelanggan, juga dapat membantu meningkatkan daya tarik kategori ini. Selain itu, menyesuaikan stok dan promosi berdasarkan pola musiman dapat membuat produk lebih relevan dengan kebutuhan pelanggan. Pendekatan ini akan membantu menjaga keseimbangan antara kategori utama dan yang kurang diminati.
